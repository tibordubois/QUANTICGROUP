# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %%
bn=gum.fastBN("A->B<-C",10)
bn
# Out:
# (pyAgrum.BayesNet<double>@0x10f80c800) BN{nodes: 3, arcs: 2, domainSize: 1000, dim: 918, mem: 7Ko 992o}

# %%
bn.cpt("B")[{"A":6,"B":3}].tolist()
# Out:
# [0.13217603903256966,
#  0.19275414562078919,
#  0.11322727426177624,
#  0.11525780122309018,
#  0.08187254204306814,
#  0.1288689107689938,
#  0.22989190859438233,
#  0.04122760426790707,
#  0.16910646516040875,
#  0.18028564321724483]

# %%
gnb.showInference(bn)

# %%
for i,j in bn.cpt("B"):
    print(i.todict(),j)
# Out:
# {'B': 0, 'A': 0, 'C': 0} 0.1083369402633754
# {'B': 1, 'A': 0, 'C': 0} 0.049277989356054895
# {'B': 2, 'A': 0, 'C': 0} 0.00686036326563662
# {'B': 3, 'A': 0, 'C': 0} 0.028530839557071787
# {'B': 4, 'A': 0, 'C': 0} 0.18599607957290784
# {'B': 5, 'A': 0, 'C': 0} 0.14052139860495239
# {'B': 6, 'A': 0, 'C': 0} 0.14151893678816788
# {'B': 7, 'A': 0, 'C': 0} 0.127560254267351
# {'B': 8, 'A': 0, 'C': 0} 0.0967867444758311
# {'B': 9, 'A': 0, 'C': 0} 0.114610453848651
# {'B': 0, 'A': 1, 'C': 0} 0.02929133727017655
# {'B': 1, 'A': 1, 'C': 0} 0.14834760487363513
# {'B': 2, 'A': 1, 'C': 0} 0.09154025317252291
# {'B': 3, 'A': 1, 'C': 0} 0.0981750053813013
# {'B': 4, 'A': 1, 'C': 0} 0.15037131377108406
# {'B': 5, 'A': 1, 'C': 0} 0.130826137039523
# {'B': 6, 'A': 1, 'C': 0} 0.1772665945833889
# {'B': 7, 'A': 1, 'C': 0} 0.1246775831551228
# {'B': 8, 'A': 1, 'C': 0} 0.029031387251145856
# {'B': 9, 'A': 1, 'C': 0} 0.02047278350209969
# {'B': 0, 'A': 2, 'C': 0} 0.09059722247230499
# ...
